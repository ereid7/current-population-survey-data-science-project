# %%
import numpy as np
import pandas as pd
import sklearn as skl
from sklearn import tree, neighbors
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
# Import dataset
data = pd.read_csv("../datasets/CPS2016_CSV.csv", index_col=None)
data.columns = ['age', 'sex', 'state', 'citizen', 'race', 'marital',
                'num_in_house', 'num_child', 'educ', 'worker_class', 'industry',
                'occupation', 'weekly_hrs', 'fam_income', 'fam_inc_50', 'ismarried']

#data = data.sample(n=1000)

# Apply 80/20 training/testing split
data_train, data_test = train_test_split(data, test_size=0.2)
data.head()
# Out:
#    age  sex  state  citizen  race  marital  num_in_house  num_child  educ  \
# 0   57    1     15        1    15        6             1          0    39
# 1   56    1     15        1    15        4             1          0    41
# 2   70    1     15        1    15        1             5          0    43
# 3   42    1     15        1    15        1             5          3    40
# 4   38    2     15        1    15        1             8          2    43
#
#    worker_class  industry  occupation  weekly_hrs  fam_income  fam_inc_50  \
# 0             4        23          21           6          15           1
# 1             4        23          22           6          16           1
# 2             4        10          22           6          16           1
# 3             2        51          22           5          10           0
# 4             4        41          10           5          16           1
#
#    ismarried
# 0          0
# 1          0
# 2          1
# 3          1
# 4          1

# %%
# Family Income < 50,000

# First show just using two variables, then check using other variables

def getColor(arr):
    colorList = [];
    for x in arr:
        if (x == 1):
            colorList.append("magenta")
        else:
            colorList.append("green")
    return colorList;

# %%
# Use cross validation

colorList = getColor(data_train['ismarried'])

T2 = neighbors.KNeighborsClassifier(n_neighbors=2)
T2.fit(data_train[['age','educ']],data_train['ismarried'])

fig,ax = plt.subplots(1, figsize=(6,6), dpi=100)
ax.scatter(data_train['age'], data_train['educ'], color=colorList, marker='x', alpha=.3)
#ax.set_aspect(1.0)
ax.set_title("Training Data")
plt.show()

# %%
# space out 400-by-400 points, from on the square from -5 to 5.
x_min, x_max = 1, 90
y_min, y_max = 30, 47
xx, yy = np.meshgrid(np.linspace(x_min, x_max, 200),
                     np.linspace(y_min, y_max, 200))

# toss them in a DataFrame for easy reference
test = pd.DataFrame({'x1': xx.ravel(), 'x2': yy.ravel()})
# Evaluate the model, so see what it says
colorPredict = getColor(T2.predict(test[['x1','x2']])) 

test.head()
# Out:
#          x1    x2
# 0  1.000000  30.0
# 1  1.447236  30.0
# 2  1.894472  30.0
# 3  2.341709  30.0
# 4  2.788945  30.0

# %%
fig,ax = plt.subplots(figsize=(10,10), dpi=100)
ax.scatter(test['x1'], test['x2'], color=colorPredict, alpha=0.05)
ax.scatter(data_train['age'], data_train['educ'],  color=colorList, s=20, alpha=.2)
ax.set_xlim(xx.min(), xx.max())
ax.set_ylim(yy.min(), yy.max())
ax.set_title("depth-2 tree prediction")
plt.show(fig)

# %%
nb = np.arange(1,30)
score_train = []
score_test = []
for d in nb:
    T = neighbors.KNeighborsClassifier(n_neighbors=d)
    T.fit(data_train[['age','num_in_house', 'num_child', 
                'educ','weekly_hrs', 'fam_income']], data_train['ismarried'])
    s_train = T.score(data_train[['age','num_in_house', 'num_child', 
                'educ','weekly_hrs', 'fam_income']], data_train['ismarried'])
    s_test = T.score(data_test[['age','num_in_house', 'num_child', 
                'educ','weekly_hrs', 'fam_income']], data_test['ismarried'])
    print(f"{d}:\t{s_train}\t{s_test}")
    score_train.append(s_train)
    score_test.append(s_test)

# %%
fig,ax = plt.subplots(1, figsize=(6,6), dpi=100)
ax.plot(nb, score_train, label="training data")
ax.plot(nb, score_test, label="testing data")
ax.set_xlabel("tree depth")
ax.set_ylabel("accuracy score")
fig.legend()
plt.show()
