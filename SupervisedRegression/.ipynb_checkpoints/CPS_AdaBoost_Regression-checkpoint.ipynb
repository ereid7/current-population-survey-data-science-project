# %% [markdown]
# # Current Population Survey Linear Regression
#
# Using Linear Regression to predict each of the numerical variables in the datset.

# %%
import numpy as np
import pandas as pd
from collections import OrderedDict
from sklearn.model_selection import train_test_split, cross_val_score, KFold

from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Import dataset
data = pd.read_csv("../datasets/CPS2016_NEW.csv", index_col=None)

# We only need numerical values for regression
data = data[['age', 'weekly_hrs', 'educ', 
                'fam_income', 'num_in_house', 'num_child']]
data = data.astype(float)

# We are going to use the entire dataset for this model
# to test on a smaller sample uncomment below
# data = data.sample(n=1000)

T = LinearRegression()

# Apply 80/20 training/testing split
# Results may vary each time the data is split
data_train, data_test = train_test_split(data, test_size=0.2)
data.head()
# Out:
#     age  weekly_hrs  educ  fam_income  num_in_house  num_child
# 0  17.0        60.0  34.0         7.0          11.0        0.0
# 1  64.0        20.0  35.0        16.0           2.0        0.0
# 2  55.0        40.0  36.0         2.0           2.0        0.0
# 3  58.0        18.0  36.0         9.0           2.0        0.0
# 4  17.0        15.0  36.0        15.0           5.0        0.0

# %%
# function to return necessary information about model
def scoreLinearRegressor(x, y, xTest, yTest):

    reg = LinearRegression()
    reg.fit(x,y)

    preds = reg.predict(xTest)
    print("R2 score : %.2f" % r2_score(yTest,preds))
    print("Mean squared error: %.2f" % mean_squared_error(yTest,preds))

    er = []
    g = 0
    for i in range(len(yTest)):
        x = (yTest[i] - preds[i]) **2
        er.append(x)
        g = g + x
    
    x = 0
    for i in range(len(er)):
       x = x + er[i]

    print ("MSE", x / len(er))

    v = np.var(er)
    print ("variance", v)

    print ("average of errors ", np.mean(er))

    m = np.mean(yTest)
    print ("average of observed values", m)

    y = 0
    for i in range(len(yTest)):
        y = y + ((yTest[i] - m) ** 2)

    print ("total sum of squares", y)
    print ("ẗotal sum of residuals ", g)
    print ("r2 calculated", 1 - (g / y)) 
    
# function to plot predictions vs training data    
def plotPredictions(data_train, data_test, prediction, target):
    fig, ax = plt.subplots(1,5, figsize=(15,3), dpi=100)
    loopData = data_train.drop(target, axis=1)
    for i, var in enumerate(loopData):
        ax[i].scatter(data_train[var], data_train[target], color='pink', marker='x', label='train')
        ax[i].scatter(data_test[var], data_test[target], color='red', marker='*', label='test', alpha=.2)
        ax[i].scatter(data_test[var], prediction, color='purple', marker='.', label='predicted', alpha=.9)
        ax[i].set_xlabel(var)
        ax[i].set_ylabel(target)
    
    # Remove duplicate labels    
    handles, labels = fig.gca().get_legend_handles_labels()
    by_label = OrderedDict(zip(labels, handles))    
    fig.legend(by_label.values(), by_label.keys())
    plt.show()

# %% [markdown]
# # Predict Number of Persons Living in Household

# %%
target = 'num_in_house'
T.fit(data_train.drop(target, axis=1), data_train[target])
prediction = T.predict(data_test.drop(target, axis=1));

plotPredictions(data_train, data_test, prediction, target)

# %%
# Score Model
xTest = np.array(data_test.drop(target, axis=1))
yTest = np.array(data_test[target])
                 
x = data_train.drop(target, axis=1)
y = data_train[target]
                 
scoreLinearRegressor(x, y, xTest, yTest)
# Out:
# R2 score : 0.41
# Mean squared error: 1.43
# MSE 1.430009618037212
# variance 16.64562615422868
# average of errors  1.4300096180372097
# average of observed values 3.0805356981268663
# total sum of squares 26688.323228666788
# ẗotal sum of residuals  15803.03628892923
# r2 calculated 0.40786702283511467

# %%
# Score with cross validation
cvscore = cross_val_score(T, data[['fam_income', 'age', 'educ', 'weekly_hrs', 'num_child']], 
                         data['num_in_house'], cv=KFold(shuffle=True, n_splits=5))
cvscore.mean()
# Out:
# 0.406155172142315

# %% [markdown]
# # Predict Number of own Children under 18 years of age

# %%
target = 'num_child'
T.fit(data_train.drop(target, axis=1), data_train[target])
prediction = T.predict(data_test.drop(target, axis=1));
plotPredictions(data_train, data_test, prediction, target)

# %%
# Score Model
xTest = np.array(data_test.drop(target, axis=1))
yTest = np.array(data_test[target])
                 
x = data_train.drop(target, axis=1)
y = data_train[target]
                 
scoreLinearRegressor(x, y, xTest, yTest)
# Out:
# R2 score : 0.36
# Mean squared error: 0.67
# MSE 0.6670806305584115
# variance 1.9285195998813203
# average of errors  0.6670806305584143
# average of observed values 0.5935209483304679
# total sum of squares 11434.09609989867
# ẗotal sum of residuals  7371.908048301006
# r2 calculated 0.35526971402957375

# %%
# Score with cross validation
cvscore = cross_val_score(T, data.drop(target, axis=1), data[target], cv=5)
cvscore.mean()
# Out:
# 0.33646322625289027

# %% [markdown]
# # Predict Family Income (Numerical Value)
# Family income is represented by integers 1 - 16, each representing increaseng income groups ranging from 'less than 5,000' to 'greater than 150,000'. Refer to dataset description for more information.

# %%
target = 'fam_income'
T.fit(data_train.drop(target, axis=1), data_train[target])
prediction = T.predict(data_test.drop(target, axis=1));
plotPredictions(data_train, data_test, prediction, target)

# %%
# Score Model
xTest = np.array(data_test.drop(target, axis=1))
yTest = np.array(data_test[target])
                 
x = data_train.drop(target, axis=1)
y = data_train[target]
                 
scoreLinearRegressor(x, y, xTest, yTest)
# Out:
# R2 score : 0.18
# Mean squared error: 9.96
# MSE 9.959230877191407
# variance 339.57816651697516
# average of errors  9.959230877191366
# average of observed values 12.220884987783911
# total sum of squares 134243.81974481884
# ẗotal sum of residuals  110059.46042384223
# r2 calculated 0.1801524969041266

# %%
# Score with cross validation
cvscore = cross_val_score(T, data.drop(target, axis=1), data[target], cv=5)
cvscore.mean()
# Out:
# 0.14424202482555218

# %% [markdown]
# # Predict Age

# %%
target = 'age'
T.fit(data_train.drop(target, axis=1), data_train[target])
prediction = T.predict(data_test.drop(target, axis=1));
plotPredictions(data_train, data_test, prediction, target)

# %%
# Score Model
xTest = np.array(data_test.drop(target, axis=1))
yTest = np.array(data_test[target])
                 
x = data_train.drop(target, axis=1)
y = data_train[target]
                 
scoreLinearRegressor(x, y, xTest, yTest)
# Out:
# R2 score : 0.07
# Mean squared error: 196.58
# MSE 196.5845107277154
# variance 48942.70769826413
# average of errors  196.58451072771584
# average of observed values 42.687901547371276
# total sum of squares 2348278.5724368934
# ẗotal sum of residuals  2172455.428051983
# r2 calculated 0.07487320561054744

# %%
# Score with cross validation
cvscore = cross_val_score(T, data.drop(target, axis=1), data[target], cv=5)
cvscore.mean()
# Out:
# 0.05109450562261184

# %% [markdown]
# # Predict Hours Worked Weekly

# %%
target = 'weekly_hrs'
T.fit(data_train.drop(target, axis=1), data_train[target])
prediction = T.predict(data_test.drop(target, axis=1));
plotPredictions(data_train, data_test, prediction, target)

# %%
# Score Model
xTest = np.array(data_test.drop(target, axis=1))
yTest = np.array(data_test[target])
                 
x = data_train.drop(target, axis=1)
y = data_train[target]
                 
scoreLinearRegressor(x, y, xTest, yTest)
# Out:
# R2 score : 0.05
# Mean squared error: 111.34
# MSE 111.34237228461839
# variance 75295.47580960953
# average of errors  111.3423722846186
# average of observed values 39.261152836847344
# total sum of squares 1288854.312912906
# ẗotal sum of residuals  1230444.5561173179
# r2 calculated 0.04531913049472425

# %%
# Score with cross validation
cvscore = cross_val_score(T, data.drop(target, axis=1), data[target], cv=5)
cvscore.mean()
# Out:
# 0.022371354360115593

# %% [markdown]
# # Predict Education Level
# Education level is represented by integers 31-46, each representing increaseng levels of education from 'less than first grade' to 'doctorates degree'. Refer to dataset description for more information.

# %%
target = 'weekly_hrs'
T.fit(data_train.drop(target, axis=1), data_train[target])
prediction = T.predict(data_test.drop(target, axis=1));
plotPredictions(data_train, data_test, prediction, target)

# %%
# Score Model
xTest = np.array(data_test.drop(target, axis=1))
yTest = np.array(data_test[target])
                 
x = data_train.drop(target, axis=1)
y = data_train[target]
                 
scoreLinearRegressor(x, y, xTest, yTest)
# Out:
# R2 score : 0.05
# Mean squared error: 111.34
# MSE 111.34237228461839
# variance 75295.47580960953
# average of errors  111.3423722846186
# average of observed values 39.261152836847344
# total sum of squares 1288854.312912906
# ẗotal sum of residuals  1230444.5561173179
# r2 calculated 0.04531913049472425

# %%
# Score with cross validation
cvscore = cross_val_score(T, data.drop(target, axis=1), data[target], cv=5)
cvscore.mean()
# Out:
# 0.022371354360115593
